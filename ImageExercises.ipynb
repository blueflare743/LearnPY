# %%
from PIL import Image
img = Image.open('word_matrix.png')
img.size
# Out:
# (1015, 559)

# %%
img2 = Image.open('mask.png')
img2.size
img2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251>

# %%
resized_word = img.resize((505,251))
resized_word
# Out:
# <PIL.Image.Image image mode=RGBA size=505x251>

# %%
piece1 = resized_word.crop((63,13, 126, 26))

# %%
img2.putalpha(100)

resized_word.paste(img2, (0,0), img2)
resized_word
# Out:
# <PIL.Image.Image image mode=RGBA size=505x251>
